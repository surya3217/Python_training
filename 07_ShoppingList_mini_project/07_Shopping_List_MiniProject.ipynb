# %%
"""
Challenge 1:
    We are going to make a "Shopping List" app. 
    Run the script to start using it.
    Put new things into the list one at a time
    Enter the word DONE - in all CAPS - to QUIT the program
    And once i quit, I want the app to show me everything thats on my list.

Hint 1:
    Step 1: Make a list to hold onto our command.
    Step 2: Print out instructions on how to use the app
    Step 3: Ask for new command
    Step 4: Add new command to our list
    Step 5: Be able to quit the app with DONE
    Step 6: print out the list
"""

def add_item(lis): 
    '''Add new item in shopping list'''
    lis.append(input('Enter new items: '))

def show(lis):
    '''Display the list items'''
    print("*****Here’s your list*****")
    for item in lis:
        print ( item )
    
def list_help():
    '''Show details of commands'''
    print('''Details of commands: 
             ADD   : add new item in list
             SHOW  : display the current list
             HELP  : give details about the options
             DONE  : quit the app''')

    
# Make a list to hold onto our items.
shopping_list = []

func= ['ADD','SHOW','HELP','DONE']    # list of all commands

while(True):
    
    print('\nList of commands to use Shopping List App:\n',func)
    command = input("Enter the command: ")   # ask for command
    
    if command in func:
        if command.upper()== 'ADD':
            add_item(shopping_list)
        
        elif command== 'SHOW':
            show(shopping_list)
        
        elif command== 'HELP':
            list_help()
        
        elif command== 'DONE':
            break
    else:
        print('Wrong input! Please try again...')
# Out:
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: ADD
# Enter new items: Table
#
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: ADD
# Enter new items: Books
#
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: ADD
# Enter new items: chairs
#
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: SHOW
# *****Here’s your list*****
# Table
# Books
# chairs
#
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: HELP
# Details of commands:
#              ADD   : add new item in list
#              SHOW  : display the current list
#              HELP  : give details about the options
#              DONE  : quit the app
#
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: ADD
# ...

# %%
"""
Challenge 2:
    If I type SHOW, I should be able to see what is currently in the list.
    If I type HELP, I should be able to see all the help for these special commands.
    Show the item in the list serially starting from 1.
Hint 2:
    Step 1: Have a HELP command
    Step 2: Have a SHOW command
    Step 3: Add a function for adding into the list 
    Step 4: Cleanup the code in general
"""

def add_item(lis): 
    '''Add new item in shopping list'''
    lis.append(input('Enter new items: '))

def show(lis):
    '''Display the list items'''
    print("*****Here’s your list*****")
    for index, item in enumerate(lis,1):
        print(index,item)
    
def list_help():
    '''Show details of commands'''
    print('''Details of commands: 
        ADD   : add new item in list
        SHOW  : display the current list
        HELP  : give details about the options
        DONE  : quit the app''')

    
# Make a list to hold onto our items.
shopping_list = []

func= ['ADD','SHOW','HELP','DONE']   # list of all commands

while(True):
    
    print('\nList of commands to use Shopping List App:\n',func)
    command = input("Enter the command: ")   # ask for command
    
    if command in func:
        if command== 'ADD':
            add_item(shopping_list)
        
        elif command== 'SHOW':
            show(shopping_list)
        
        elif command== 'HELP':
            list_help()
        
        elif command== 'DONE':
            break
    else:
        print('Wrong input! Please try again...')
# Out:
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: help
# Wrong input! Please try again...
#
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: HELP
# Details of commands:
#         ADD   : add new item in list
#         SHOW  : display the current list
#         HELP  : give details about the options
#         DONE  : quit the app
#
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: ADD
# Enter new items: Table
#
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: ADD
# Enter new items: Books
#
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: ADD
# Enter new items: Chairs
#
# List of commands to use Shopping List App:
#  ['ADD', 'SHOW', 'HELP', 'DONE']
# Enter the command: SHOW
# *****Here’s your list*****
# 1 Table
# 2 Books
# 3 Chairs
# ...

# %%
"""
Challenge 3:
    User can enter SHOW or Show or show, similar for DONE and HELP, but the 
    program should do the required job. Let us accept command using a comma 
    separated string.
    Also there should be a functionality to add an item at a specific index
    There should be a functionality to remove command from the list at a specific 
    index using REMOVE
"""

def add_item(lis): 
    '''Add new item in shopping list'''
    lis.append(input('Enter new items: '))

def show(lis):
    '''Display the list items'''
    print("*****Here’s your list*****")
    for index, item in enumerate(lis,1):
        print(index,item)
        
def list_help():
    '''Show details of commands'''
    print('''Details of commands: 
             ADD   : add new item in list
             SHOW  : display the current list
             INSERT: add an item at a specific index
             REMOVE: remove command from the list at a specific index
             HELP  : give details about the options
             DONE  : quit the app\n''')

def insert_item(lis):
    '''Insert item in shopping list at specific index'''
    index, val= input('Enter the space(' ') separated specific index and item: ').split(' ')
    lis.insert(int(index)-1,val)

def remove_item(lis):
    '''Remove item from shopping list'''
    index= input('Enter the index to remove item: ')
    print('Removed item:',shopping_list.pop(int(index)-1))    


# Make a list to hold onto our list
shopping_list = []

func= ['ADD','REMOVE','INSERT','SHOW','HELP','DONE']   # list of all commands

while(True):
    
    print('\nList of commands to use Shopping List App:\n',func)
    command = input("Enter the command: ")     # ask for command
    
    if command.upper() in func:
        if command.upper()== 'ADD':
            add_item(shopping_list)
        
        elif command.upper()== 'SHOW':
            show(shopping_list)
        
        elif command.upper()== 'HELP':
            list_help()
            
        elif command.upper()== 'INSERT':
            insert_item(shopping_list)
            
        elif command.upper()== 'REMOVE':
            remove_item(shopping_list)
        
        elif command.upper()== 'DONE':
            break
    else:
        print('Wrong input! Please try again...')
# Out:
# List of commands to use Shopping List App:
#  ['ADD', 'REMOVE', 'INSERT', 'SHOW', 'HELP', 'DONE']
# Enter the command: Add
# Enter new items: Table
#
# List of commands to use Shopping List App:
#  ['ADD', 'REMOVE', 'INSERT', 'SHOW', 'HELP', 'DONE']
# Enter the command: add
# Enter new items: Books
#
# List of commands to use Shopping List App:
#  ['ADD', 'REMOVE', 'INSERT', 'SHOW', 'HELP', 'DONE']
# Enter the command: add
# Enter new items: Pens
#
# List of commands to use Shopping List App:
#  ['ADD', 'REMOVE', 'INSERT', 'SHOW', 'HELP', 'DONE']
# Enter the command: show
# *****Here’s your list*****
# 1 Table
# 2 Books
# 3 Pens
#
# List of commands to use Shopping List App:
#  ['ADD', 'REMOVE', 'INSERT', 'SHOW', 'HELP', 'DONE']
# Enter the command: insert
# Enter the space() separated specific index and item: 3 copies
#
# List of commands to use Shopping List App:
#  ['ADD', 'REMOVE', 'INSERT', 'SHOW', 'HELP', 'DONE']
# Enter the command: add
# Enter new items: Cover
#
# ...
